# %% [markdown]
# ### Test Flow Warp

# %%
import cv2
import numpy as np

# %%
import cv2
import numpy as np
# Read and convert to grayscale
img1 = cv2.imread('frame1.png', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('frame2.png', cv2.IMREAD_GRAYSCALE)
# Compute optical flow (returns a [H, W, 2] array)
flow = cv2.calcOpticalFlowFarneback(
  prev=img1,
  next=img2,
  flow=None,
  pyr_scale=0.5,
  levels=3,
  winsize=15,
  iterations=3,
  poly_n=5,
  poly_sigma=1.2,
  flags=0
)
